# %% [markdown]
# D:\letsgodeep\Internship\Unque\Jest-assignment\index.ts:1
# import { createRequire } from 'module';
#                               ^
#
#
# ReferenceError: Cannot access 'require' before initialization
#     at mongoose (D:\letsgodeep\Internship\Unque\Jest-assignment\index.ts:1:31)
#     at Object.<anonymous> (D:\letsgodeep\Internship\Unque\Jest-assignment\index.ts:43:8135)
#     at Module._compile (node:internal/modules/cjs/loader:1565:14)
#     at Object.transformer (D:\letsgodeep\Internship\Unque\Jest-assignment\node_modules\tsx\dist\register-OY9cqBEN.cjs:9:3619)
#     at Module.load (node:internal/modules/cjs/loader:1318:32)
#     at Function._load (node:internal/modules/cjs/loader:1128:12)
#     at TracingChannel.traceSync (node:diagnostics_channel:322:14)
#     at wrapModuleLoad (node:internal/modules/cjs/loader:219:24)
#     at cjsLoader (node:internal/modules/esm/translators:263:5)
#     at ModuleWrap.<anonymous> (node:internal/modules/esm/translators:196:7)
#
# Node.js v22.12.0
#
# CommonJS `require` used in ESM project

# %% [markdown]
# 2) const app = eaxpress();

# %% [markdown]
# 3) as it was in esm then we must have to import along with the extension.

# %% [markdown]
# 4) I dont know why but there was a long string.. that is this
